# %% [markdown]
# Class work
#
# create a NumPy array called nums containing the values 1, 3, 5, 7, 9, print the array, add 2 to each element and store the result in a new array, multiply each element by 3, and then use NumPy methods to find and print the sum, maximum value, and mean of the original array.

# %%
import numpy as np

# %%
nums = np.array([1, 3, 5, 7, 9])
print(nums)
# Out:
# [1 3 5 7 9]

# %%
new_array = nums + 2
print(new_array)
# Out:
# [ 3  5  7  9 11]

# %%
latest_array = new_array * 3
print(latest_array)
# Out:
# [ 9 15 21 27 33]

# %%
total_sum = np.sum(nums)
print(f"sum: {total_sum}")
maximum_value = np.max(nums)
print(f"maximum_value: {maximum_value}")
mean = np.mean(nums)
print(f"mean: {mean}")
# Out:
# sum: 25
# maximum_value: 9
# mean: 5.0
