# %%
import numpy as np
num_1 = np.array([1,3,5,7,9])

# %%
print(num_1)
# Out:
# [1 3 5 7 9]

# %%
num_1 =np.array(num_1 + 2)

# %%
print(num_1)
# Out:
# [ 3  5  7  9 11]

# %%
num_1 = np.array(num_1 * 3)

# %%
print(num_1)
# Out:
# [ 9 15 21 27 33]

# %%
total = np.sum(num_1)
Maximum = np.max(num_1)
Average = np.mean(num_1)
print('sum:', total)
print('Maximum Value:', Maximum)
print('mean:', Average)
# Out:
# sum: 105
# Maximum Value: 33
# mean: 21.0
